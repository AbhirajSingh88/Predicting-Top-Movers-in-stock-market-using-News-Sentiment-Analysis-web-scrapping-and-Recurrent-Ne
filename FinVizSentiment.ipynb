# %%
pip install twython
# Out:
# Collecting twython
#   Downloading https://files.pythonhosted.org/packages/24/80/579b96dfaa9b536efde883d4f0df7ea2598a6f3117a6dd572787f4a2bcfb/twython-3.8.2-py3-none-any.whl
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from twython) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.1.0)
# Installing collected packages: twython
# Successfully installed twython-3.8.2

# %%
# Import libraries
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen
from urllib.request import Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer

n = 10 #Number of articles per ticker
tickers = ['LEJU', 'SAM', 'VOXX', 'LOOP', 'ADAP', 'MAT' , 'SIM', 'NXGN', 'HYMC', 'TSLA', 'AAPL', 'MSFT','LLNW','TC','USX','GLBS']

# %%
# Get Data
finviz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

for ticker in tickers:
    url = finviz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    resp = urlopen(req)    
    html = BeautifulSoup(resp, features="lxml")
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table

try:
    for ticker in tickers:
        df = news_tables[ticker]
        df_tr = df.findAll('tr')
    
        print ('\n')
        print ('Recent News Headlines for {}: '.format(ticker))
        
        for i, table_row in enumerate(df_tr):
            a_text = table_row.a.text
            td_text = table_row.td.text
            td_text = td_text.strip()
            print(a_text,'(',td_text,')')
            if i == n-1:
                break
except KeyError:
    pass
# Out:
# Recent News Headlines for LEJU:
# Is Now The Time To Look At Buying Leju Holdings Limited (NYSE:LEJU)? ( Oct-26-20 09:57AM )
# A Look Into Leju Holdings Price Over Earnings ( Oct-23-20 04:01PM )
# A Trio of Graham-Style Stocks to Consider ( Oct-07-20 01:00PM )
# Slammed 28% Leju Holdings Limited (NYSE:LEJU) Screens Well Here But There Might Be A Catch ( Sep-18-20 08:39AM )
# Take Care Before Diving Into The Deep End On Leju Holdings Limited (NYSE:LEJU) ( Aug-29-20 10:31AM )
# Leju Holdings Ltd (LEJU) Q2 2020 Earnings Call Transcript ( Aug-27-20 01:24PM )
# Leju Reports First Half Year 2020 Results ( Aug-20-20 05:51AM )
# Leju to Report First Half 2020 Financial Results on August 20, 2020 ( Aug-06-20 11:00PM )
# E-House to Become Leju's Majority Shareholder; E-House, Alibaba and Leju to Jointly Build Online Real Estate Platform; Alibaba to Increase Stake in E-House ( Jul-31-20 09:40AM )
# Announcing: Leju Holdings (NYSE:LEJU) Stock Increased An Energizing 158% In The Last Year ( Jul-29-20 01:36PM )
#
#
# Recent News Headlines for SAM:
# AB InBev (BUD) Q3 Earnings Top Estimates on Robust Volume ( Oct-29-20 11:55AM )
# Boston Beer is Set for a Strong Close to 2020 ( Oct-28-20 12:00PM )
# Is Boston Beer a Buy? ( 08:31AM )
# Top Consumer Staples Stocks for November 2020 ( Oct-27-20 02:13PM )
# Walmart CEO: Consumers are stocking up again as coronavirus rages on ( Oct-26-20 01:43PM )
# Boston Beer Soars 19% On 3Q Profit Beat; Analyst Sees 29% Downside ( 02:33AM )
# The Boston Beer Company, Inc. Just Beat Earnings Expectations: Here's What Analysts Think Will Happen Next ( Oct-25-20 10:06AM )
# Should You Be Adding Boston Beer Company (NYSE:SAM) To Your Watchlist Today? ( Oct-24-20 09:51AM )
# Dow Jones Collapses To Mark Worst Month Since March As Election Looms Large ( 04:50PM )
# CORRECTED-US STOCKS-Tech slide, pandemic surge slam Wall Street, biggest weekly loss since March ( 04:43PM )
# Stock Market Today: Big Tech Beatdown Keeps Stocks in a Slump ( 04:33PM )
#
#
# Recent News Headlines for MSFT:
# Google reveals a new Windows zero-day bug it says is under active attack ( Oct-30-20 05:04PM )
# 'Financials need a steepening yield curve': Richard Bernstein ( 04:58PM )
# Trump-Biden Election Looms Large As Dow Jones Collapses ( 04:50PM )
# Are Technology Companies Losing Their Earnings Power? ( 04:29PM )
# 5 Tech Titans Just Posted Earnings. Here Are the Best Nuggets. ( 03:49PM )
# Alphabet Was the Winner in Big Techs Earnings Extravaganza. Heres Why. ( 01:27PM )
# Cloud infrastructure revenue grows 33% this quarter to almost $33B ( 11:23AM )
# Zacks Investment Ideas feature highlights: Microsoft, Amazon, Zoom Video, Adobe and NVIDIA ( 10:33AM )
# Big Tech's Cloud Gaming Competition Heats Up ( 09:55AM )
# Coronavirus Continues to Boost Videogame Sales: 4 Winners ( 08:44AM )
#
#
# Recent News Headlines for LLNW:
# Why I Remain Unfazed After Limelight Networks' Epic Stock Price Drop ( Oct-28-20 11:44AM )
# Is Limelight Networks' Post-Earnings Dip a Buying Opportunity? ( Oct-27-20 11:00AM )
# Why Limelight Networks Stock Crashed on Friday ( Oct-23-20 11:43AM )
# Limelight Networks Falls Sharply After Reporting Q3 Losses ( 10:54AM )
# Analyzing Limelight Networks's Unusual Options Activity ( 10:18AM )
# 3 Top Stocks That Aren't on Wall Street's Radar ( 10:04AM )
# Limelight Networks (LLNW) Q3 2020 Earnings Call Transcript ( 01:31AM )
# Limelight Networks (LLNW) Reports Q3 Loss, Tops Revenue Estimates ( Oct-22-20 05:35PM )
# Limelight Networks: Q3 Earnings Insights ( 04:15PM )
# Limelight Networks Reports Financial Results for the Third Quarter of 2020 ( 04:01PM )
#
#
# Recent News Headlines for TC:
# Why TuanChe Stock Doubled Today ( Oct-22-20 05:01PM )
# TuanChe Announces ADS Ratio Change ( Oct-20-20 06:00AM )
# TuanChe Limited Announces Results of Annual General Meeting of Shareholders ( Oct-19-20 06:00AM )
# TuanChe Announces Unaudited Second Quarter 2020 Financial Results ( Sep-18-20 06:00AM )
# TuanChe Limited to Report Second Quarter 2020 Financial Results on September 18, 2020 ( Sep-14-20 06:00AM )
# TuanChe to Hold 2020 Annual General Meeting on October 19, 2020 ( Sep-08-20 06:00AM )
# TuanChe - Strengthening Online Initiatives to Navigate through COVID-19 Challenges ( Jul-02-20 05:00PM )
# TuanChe Ltd. to Host Earnings Call ( 06:00AM )
# TuanChe Announces Unaudited First Quarter 2020 Financial Results ( 06:00AM )
# TuanChe Limited to Report First Quarter 2020 Financial Results on July 2, 2020 ( Jun-24-20 06:00AM )
#
#
# Recent News Headlines for USX:
# U.S. Xpress Graduates First Full Ride Scholarship Participants ( Oct-27-20 08:17AM )
# Need To Know: U.S. Xpress Enterprises, Inc. (NYSE:USX) Insiders Have Been Buying Shares ( Oct-23-20 12:51PM )
# Why Shares of U.S. Xpress Are Falling Today ( 12:21PM )
# U.S. Xpress OR Improves; Driver Squeeze Limits Miles Driven ( Oct-22-20 07:23PM )
# Recap: U.S. Xpress Enterprises Q3 Earnings ( 04:54PM )
# U.S. Xpress Enterprises Reports Third Quarter 2020 Results ( 04:10PM )
# US Xpress Enterprises, Inc. to Host Earnings Call ( 03:00PM )
# U.S. Xpress Enterprises, Inc. Announces Third Quarter 2020 Financial Results Release Date and Conference Call ( Oct-12-20 04:10PM )
# The 3 Most Expensive Stocks to Avoid During a Market Crash ( Oct-04-20 08:07AM )
# Trucking industry pay is going to have to go up a lot more than 20% to attract new workers: US Xpress CEO ( Sep-30-20 02:11PM )
#
#
# Recent News Headlines for GLBS:
# Globus Maritime Limited Announces the Delivery of a 2015-Built Kamsarmax Dry Bulk Vessel Galaxy Globe, Expanding Fleet to Six Vessels ( Oct-29-20 09:00AM )
# Globus Maritime Limited Announces Reverse Stock Split ( Oct-19-20 04:05PM )
# Globus Maritime Limited Announces the Acquisition of a 2015-Built Kamsarmax Dry Bulk Carrier, Expanding Fleet to Six Vessels ( Oct-12-20 09:00AM )
# Globus Maritime Limited Reports Financial Results for the Quarter and Six-Month Period Ended June 30, 2020 ( Sep-25-20 04:05PM )
# Globus Maritime Announces Results of Annual Meeting of Shareholders ( Sep-24-20 04:05PM )
# Globus Maritime Sets Date for the Release of Second Quarter and First Half 2020 Results ( Sep-23-20 04:05PM )
# Globus Maritime Announces Annual Meeting of Shareholders ( Aug-24-20 04:05PM )
# Globus Maritime Limited Announces Closing of $15.0 Million Registered Direct Offering ( Jul-27-20 04:05PM )
# Globus Maritime Limited Announces Pricing of $15.0 Million Registered Direct Offering ( Jul-17-20 09:20AM )
# Globus Maritime Announces Closing of Transaction ( Jul-01-20 09:07AM )

# %%
# Iterate through the news
parsed_news = []
for file_name, news_table in news_tables.items():
    for x in news_table.findAll('tr'):
        text = x.a.get_text() 
        date_scrape = x.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        ticker = file_name.split('_')[0]
        
        parsed_news.append([ticker, date, time, text])

# %%
import nltk
nltk.download('vader_lexicon')
# Sentiment Analysis
analyzer = SentimentIntensityAnalyzer()

columns = ['Ticker', 'Date', 'Time', 'Headline']
news = pd.DataFrame(parsed_news, columns=columns)
scores = news['Headline'].apply(analyzer.polarity_scores).tolist()

df_scores = pd.DataFrame(scores)
news = news.join(df_scores, rsuffix='_right')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# View Data 
news['Date'] = pd.to_datetime(news.Date).dt.date

unique_ticker = news['Ticker'].unique().tolist()
news_dict = {name: news.loc[news['Ticker'] == name] for name in unique_ticker}

values = []
for ticker in tickers: 
    dataframe = news_dict[ticker]
    dataframe = dataframe.set_index('Ticker')
    dataframe = dataframe.drop(columns = ['Headline'])
    print ('\n')
    print (dataframe.head())
    
    mean = round(dataframe['compound'].mean(), 2)
    values.append(mean)
    
df = pd.DataFrame(list(zip(tickers, values)), columns =['Ticker', 'Mean Sentiment']) 
df = df.set_index('Ticker')
df = df.sort_values('Mean Sentiment', ascending=False)
print ('\n')
print (df)
# Out:
#               Date     Time    neg    neu    pos  compound
# Ticker
# LEJU    2020-10-26  09:57AM  0.147  0.853  0.000   -0.2263
# LEJU    2020-10-23  04:01PM  0.000  1.000  0.000    0.0000
# LEJU    2020-10-07  01:00PM  0.000  1.000  0.000    0.0000
# LEJU    2020-09-18  08:39AM  0.119  0.750  0.131    0.0516
# LEJU    2020-08-29  10:31AM  0.116  0.610  0.274    0.3818
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# SAM     2020-10-29  11:55AM  0.000  0.656  0.344    0.4939
# SAM     2020-10-28  12:00PM  0.000  0.708  0.292    0.5106
# SAM     2020-10-28  08:31AM  0.000  1.000  0.000    0.0000
# SAM     2020-10-27  02:13PM  0.000  0.769  0.231    0.2023
# SAM     2020-10-26  01:43PM  0.237  0.763  0.000   -0.4767
#
#
#               Date     Time  neg    neu    pos  compound
# Ticker
# VOXX    2020-10-26  04:01PM  0.0  0.610  0.390    0.7506
# VOXX    2020-10-14  08:00AM  0.0  1.000  0.000    0.0000
# VOXX    2020-10-13  04:01PM  0.0  1.000  0.000    0.0000
# VOXX    2020-10-07  07:16AM  0.0  0.815  0.185    0.3597
# VOXX    2020-10-06  11:16AM  0.0  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# LOOP    2020-10-30  03:37PM  0.064  0.838  0.098    0.2577
# LOOP    2020-10-30  03:15PM  0.220  0.608  0.172   -0.3400
# LOOP    2020-10-30  02:10PM  0.059  0.872  0.069    0.0772
# LOOP    2020-10-30  01:20PM  0.084  0.747  0.169    0.4084
# LOOP    2020-10-30  12:40PM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time  neg    neu    pos  compound
# Ticker
# ADAP    2020-10-22  08:00AM  0.0  1.000  0.000     0.000
# ADAP    2020-10-16  12:41PM  0.0  1.000  0.000     0.000
# ADAP    2020-10-15  04:40PM  0.0  1.000  0.000     0.000
# ADAP    2020-10-13  12:04PM  0.0  1.000  0.000     0.000
# ADAP    2020-10-09  06:18AM  0.0  0.845  0.155     0.296
#
#
#               Date     Time  neg    neu    pos  compound
# Ticker
# MAT     2020-10-30  10:15AM  0.0  1.000  0.000    0.0000
# MAT     2020-10-30  10:04AM  0.0  1.000  0.000    0.0000
# MAT     2020-10-28  06:52PM  0.0  0.750  0.250    0.3252
# MAT     2020-10-27  01:29PM  0.0  0.755  0.245    0.3818
# MAT     2020-10-27  10:01AM  0.0  0.656  0.344    0.7425
#
#
#               Date     Time  neg    neu    pos  compound
# Ticker
# SIM     2020-10-28  12:03PM  0.0  1.000  0.000    0.0000
# SIM     2020-09-02  03:00PM  0.0  1.000  0.000    0.0000
# SIM     2020-07-27  07:43PM  0.0  1.000  0.000    0.0000
# SIM     2020-07-07  01:39PM  0.0  0.833  0.167    0.2023
# SIM     2020-07-03  01:11PM  0.0  0.583  0.417    0.6124
#
#
#               Date     Time  neg    neu    pos  compound
# Ticker
# NXGN    2020-10-28  04:05PM  0.0  0.833  0.167    0.4215
# NXGN    2020-10-28  08:00AM  0.0  1.000  0.000    0.0000
# NXGN    2020-10-26  01:31PM  0.0  1.000  0.000    0.0000
# NXGN    2020-10-26  09:38AM  0.0  0.769  0.231    0.3400
# NXGN    2020-10-26  02:45AM  0.0  1.000  0.000    0.0000
#
#
#               Date     Time  neg  neu  pos  compound
# Ticker
# HYMC    2020-10-27  07:05AM  0.0  1.0  0.0       0.0
# HYMC    2020-10-20  05:58PM  0.0  1.0  0.0       0.0
# HYMC    2020-10-07  08:42AM  0.0  1.0  0.0       0.0
# HYMC    2020-10-06  12:56PM  0.0  1.0  0.0       0.0
# HYMC    2020-10-02  06:23AM  0.0  1.0  0.0       0.0
#
#
#               Date     Time  neg  neu  pos  compound
# Ticker
# TSLA    2020-10-30  06:58PM  0.0  1.0  0.0       0.0
# TSLA    2020-10-30  05:14PM  0.0  1.0  0.0       0.0
# TSLA    2020-10-30  04:15PM  0.0  1.0  0.0       0.0
# TSLA    2020-10-30  03:38PM  0.0  1.0  0.0       0.0
# TSLA    2020-10-30  12:16PM  0.0  1.0  0.0       0.0
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# AAPL    2020-10-30  06:55PM  0.000  1.000  0.000    0.0000
# AAPL    2020-10-30  06:14PM  0.000  0.732  0.268    0.2960
# AAPL    2020-10-30  06:01PM  0.184  0.816  0.000   -0.4019
# AAPL    2020-10-30  05:58PM  0.000  1.000  0.000    0.0000
# AAPL    2020-10-30  05:14PM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# MSFT    2020-10-30  05:04PM  0.196  0.633  0.171   -0.1027
# MSFT    2020-10-30  04:58PM  0.000  1.000  0.000    0.0000
# MSFT    2020-10-30  04:50PM  0.388  0.612  0.000   -0.4215
# MSFT    2020-10-30  04:29PM  0.302  0.698  0.000   -0.3818
# MSFT    2020-10-30  03:49PM  0.000  0.682  0.318    0.6369
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# LLNW    2020-10-28  11:44AM  0.189  0.811  0.000   -0.2732
# LLNW    2020-10-27  11:00AM  0.000  0.682  0.318    0.4215
# LLNW    2020-10-23  11:43AM  0.000  1.000  0.000    0.0000
# LLNW    2020-10-23  10:54AM  0.278  0.722  0.000   -0.4019
# LLNW    2020-10-23  10:18AM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu  pos  compound
# Ticker
# TC      2020-10-22  05:01PM  0.000  1.000  0.0    0.0000
# TC      2020-10-20  06:00AM  0.000  1.000  0.0    0.0000
# TC      2020-10-19  06:00AM  0.174  0.826  0.0   -0.2263
# TC      2020-09-18  06:00AM  0.000  1.000  0.0    0.0000
# TC      2020-09-14  06:00AM  0.137  0.863  0.0   -0.2263
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# USX     2020-10-27  08:17AM  0.000  1.000  0.000    0.0000
# USX     2020-10-23  12:51PM  0.000  0.845  0.155    0.2960
# USX     2020-10-23  12:21PM  0.163  0.612  0.224    0.1531
# USX     2020-10-22  07:23PM  0.000  0.741  0.259    0.4215
# USX     2020-10-22  04:54PM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu  pos  compound
# Ticker
# GLBS    2020-10-29  09:00AM  0.095  0.905  0.0   -0.2263
# GLBS    2020-10-19  04:05PM  0.241  0.759  0.0   -0.2263
# GLBS    2020-10-12  09:00AM  0.106  0.894  0.0   -0.2263
# GLBS    2020-09-25  04:05PM  0.112  0.888  0.0   -0.2263
# GLBS    2020-09-24  04:05PM  0.000  1.000  0.0    0.0000
#
#
#         Mean Sentiment
# Ticker
# NXGN              0.17
# SAM               0.13
# LLNW              0.13
# LOOP              0.12
# SIM               0.12
# VOXX              0.11
# TSLA              0.11
# MSFT              0.11
# ADAP              0.10
# USX               0.10
# MAT               0.07
# LEJU              0.05
# AAPL              0.02
# HYMC              0.00
# GLBS             -0.03
# TC               -0.05
